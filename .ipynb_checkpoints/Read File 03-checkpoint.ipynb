# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## DATA THROUGH CLIPBOARD

# %%
pd.read_clipboard()
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %%
clipboard = pd.read_clipboard()

# %%
clipboard
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %% [markdown]
# ## READING CSV

# %%
csv = pd.read_csv('data/insurence.csv')

# %%
csv
# Out:
#      age     sex     bmi  children smoker     region      charges   id
# 0     19  female  27.900         0    yes  southwest  16884.92400    1
# 1     18    male  33.770         1     no  southeast   1725.55230    2
# 2     28    male  33.000         3     no  southeast   4449.46200    3
# 3     33    male  22.705         0     no  northwest  21984.47061    4
# 4     32    male  28.880         0     no  northwest   3866.85520    5
# ..   ...     ...     ...       ...    ...        ...          ...  ...
# 495   20    male  27.930         0     no  northeast   1967.02270  496
# 496   31  female  23.600         2     no  southwest   4931.64700  497
# 497   45    male  28.700         2     no  southwest   8027.96800  498
# 498   44  female  23.980         2     no  southeast   8211.10020  499
# 499   62  female  39.200         0     no  southwest  13470.86000  500
#
# [500 rows x 8 columns]

# %% [markdown]
# ## READING EXCELS

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
excel = pd.read_excel('data/file_example_XLS_50.xls')

# %%
excel
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %% [markdown]
# ## Reading Json

# %%
import requests

url = "https://rottentomato.p.rapidapi.com/get-poster-gallery"

querystring = {"versions_gallery_id":"/movies/mission-impossible-the-final-reckoning-i9603208/g/gkuris"}

headers = {
	"x-rapidapi-key": "73291e3eaemsh9307fadc167057fp1bf07cjsnf6bc64600f61",
	"x-rapidapi-host": "rottentomato.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'country': 'US', 'detail_url': 'https://www.cinematerial.com/movies/mission-impossible-the-final-reckoning-i9603208/p/mfglvqlo', 'dimensions': '3958*5000px', 'image_url': 'https://cdn.cinematerial.com/p/500x/mfglvqlo/mission-impossible-the-final-reckoning-movie-poster-md.jpg?v=1747862253', 'show_title': 'Mission: Impossible - The Final Reckoning', 'synopsis': "Ethan Hunt and team continue their search for the terrifying AI known as the Entity — which has infiltrated intelligence networks all over the globe — with the world's governments and a mysterious ghost from Hunt's past on their trail. Joined by new allies and armed with the means to shut the Entity down for good, Hunt is in a race against time to prevent the world as we know...", 'type': 'Mission: Impossible - The Final Reckoning Poster'}, {'country': 'CZ', 'detail_url': 'https://www.cinematerial.com/movies/mission-impossible-the-final-reckoning-i9603208/p/lbvtetvf', 'dimensions': '3532*5000px', 'image_url': 'https://cdn.cin
# ...

# %%
data = response.json()

# %%
df = pd.json_normalize(data)

# %%
df
# Out:
#    country                                         detail_url   dimensions  \
# 0       US  https://www.cinematerial.com/movies/mission-im...  3958*5000px
# 1       CZ  https://www.cinematerial.com/movies/mission-im...  3532*5000px
# 2     None  https://www.cinematerial.com/movies/mission-im...  3532*5000px
# 3       CZ  https://www.cinematerial.com/movies/mission-im...  3532*5000px
# 4       IL  https://www.cinematerial.com/movies/mission-im...  3500*5000px
# 5       FR  https://www.cinematerial.com/movies/mission-im...  3235*5000px
# 6       NO  https://www.cinematerial.com/movies/mission-im...  2480*3508px
# 7       DE  https://www.cinematerial.com/movies/mission-im...  2480*3508px
# 8       JP  https://www.cinematerial.com/movies/mission-im...  2119*3000px
# 9       SE  https://www.cinematerial.com/movies/mission-im...  2105*2976px
# 10      JP  https://www.cinematerial.com/movies/mission-im...  2064*2919px
# ...

# %% [markdown]
# ## THROGH SEABORN

# %%
import seaborn as sns

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
