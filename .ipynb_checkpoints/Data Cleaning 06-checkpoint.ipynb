# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('taxis')

# %%
BACKUP = df.copy()

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.size
# Out:
# 90062

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df.tail()
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total  color      payment          pickup_zone  \
# 6428  1.06    0.0   6.36  green  credit card    East Harlem North
# 6429  0.00    0.0  58.80  green  credit card              Jamaica
# 6430  0.00    0.0  17.30  green         cash  Crown Heights North
# 6431  0.00    0.0   6.80  green  credit card        East New York
# 6432  3.36    0.0  20.16  green  credit card          Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# ...

# %%
df.sample(100)
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 5328 2019-03-14 17:25:51 2019-03-14 17:41:21           2      1.60  11.00
# 6283 2019-03-05 12:44:30 2019-03-05 12:49:34           1      0.93   5.50
# 3611 2019-03-20 19:34:37 2019-03-20 20:03:00           1      5.07  21.50
# 4958 2019-03-26 19:41:00 2019-03-26 19:48:14           1      1.05   6.50
# 1021 2019-03-06 20:29:15 2019-03-06 20:37:55           1      1.10   7.00
# ...                  ...                 ...         ...       ...    ...
# 5884 2019-03-11 10:29:53 2019-03-11 10:32:27           2      0.68   4.00
# 5844 2019-03-09 16:50:00 2019-03-09 17:29:42           1     10.83  33.01
# 5771 2019-03-23 00:32:50 2019-03-23 00:41:12           1      1.90   8.50
# 1054 2019-03-29 17:47:06 2019-03-29 17:48:38           5      0.40   3.50
# 397  2019-03-23 02:42:30 2019-03-23 02:46:36           1      0.75   5.00
#
#        tip  tolls  total   color      payment              pickup_zone  \
# ...

# %%
df["tolls"] > 0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: tolls, Length: 6433, dtype: bool

# %%
df[df["tolls"] > 0]
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 22   2019-03-28 17:20:54 2019-03-28 17:55:57           1      9.82  31.5
# 43   2019-03-27 19:39:16 2019-03-27 20:00:26           1      9.50  28.0
# 56   2019-03-05 17:57:00 2019-03-05 18:45:25           2     19.59  52.0
# 92   2019-03-28 07:05:19 2019-03-28 07:41:14           0     10.60  33.5
# 104  2019-03-28 13:29:48 2019-03-28 13:56:36           3      9.50  30.0
# ...                  ...                 ...         ...       ...   ...
# 6279 2019-03-13 13:04:49 2019-03-13 13:44:25           1     12.06  39.0
# 6292 2019-03-05 20:14:04 2019-03-05 21:25:59           1     22.81  70.0
# 6362 2019-03-08 03:34:43 2019-03-08 04:20:37           1     21.37  62.5
# 6383 2019-03-24 19:42:37 2019-03-24 19:59:38           1      8.88  25.5
# 6417 2019-03-10 12:10:45 2019-03-10 12:43:05           2     11.17  35.0
#
#        tip  tolls  total   color      payment        pickup_zone  \
# ...

# %%
df.count()
# Out:
# pickup             6433
# dropoff            6433
# passengers         6433
# distance           6433
# fare               6433
# tip                6433
# tolls              6433
# total              6433
# color              6433
# payment            6389
# pickup_zone        6407
# dropoff_zone       6388
# pickup_borough     6407
# dropoff_borough    6388
# dtype: int64

# %%
df.isna()
# Out:
#       pickup  dropoff  passengers  distance   fare    tip  tolls  total  \
# 0      False    False       False     False  False  False  False  False
# 1      False    False       False     False  False  False  False  False
# 2      False    False       False     False  False  False  False  False
# 3      False    False       False     False  False  False  False  False
# 4      False    False       False     False  False  False  False  False
# ...      ...      ...         ...       ...    ...    ...    ...    ...
# 6428   False    False       False     False  False  False  False  False
# 6429   False    False       False     False  False  False  False  False
# 6430   False    False       False     False  False  False  False  False
# 6431   False    False       False     False  False  False  False  False
# 6432   False    False       False     False  False  False  False  False
#
#       color  payment  pickup_zone  dropoff_zone  pickup_borough  \
# ...

# %%
df['pickup'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: pickup, Length: 6433, dtype: bool

# %%
df[df['pickup'].isna()]
# Out:
# Empty DataFrame
# Columns: [pickup, dropoff, passengers, distance, fare, tip, tolls, total, color, payment, pickup_zone, dropoff_zone, pickup_borough, dropoff_borough]
# Index: []

# %% [markdown]
# #### 1.Ignore, 2.Fill with 0 or 1 or average or minimun or maximum ,3.Remove the row

# %%
df['payment']
# Out:
# 0       credit card
# 1              cash
# 2       credit card
# 3       credit card
# 4       credit card
#            ...
# 6428    credit card
# 6429    credit card
# 6430           cash
# 6431    credit card
# 6432    credit card
# Name: payment, Length: 6433, dtype: object

# %%
df['payment'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: payment, Length: 6433, dtype: bool

# %%
df[df['payment'].isna()]
# Out:
#                   pickup             dropoff  passengers  distance  fare  tip  \
# 7    2019-03-22 12:47:13 2019-03-22 12:58:17           0       1.4   8.5  0.0
# 445  2019-03-19 06:57:14 2019-03-19 07:00:08           1       1.3   5.5  0.0
# 491  2019-03-07 07:11:33 2019-03-07 07:11:39           1       1.6   2.5  0.0
# 545  2019-03-27 11:03:43 2019-03-27 11:14:34           1       4.2  15.0  0.0
# 621  2019-03-15 17:16:35 2019-03-15 17:25:01           1       1.3   7.5  0.0
# 770  2019-03-02 03:16:59 2019-03-02 03:17:06           0       9.4   2.5  0.0
# 913  2019-03-23 11:26:58 2019-03-23 11:35:17           2       1.3   7.5  0.0
# 953  2019-03-08 02:58:37 2019-03-08 03:19:27           2       6.9  23.5  0.0
# 1207 2019-03-08 15:41:20 2019-03-08 15:41:23           1       0.0   2.5  0.0
# 1372 2019-03-12 09:19:44 2019-03-12 09:43:09           1       1.6  14.5  0.0
# 1566 2019-03-18 02:20:59 2019-03-18 02:49:24           1       6.0  23.0  0.0
# ...

# %%
df['payment'].fillna('other')
# Out:
# 0       credit card
# 1              cash
# 2       credit card
# 3       credit card
# 4       credit card
#            ...
# 6428    credit card
# 6429    credit card
# 6430           cash
# 6431    credit card
# 6432    credit card
# Name: payment, Length: 6433, dtype: object

# %%
df = BACKUP.copy()

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %% [markdown]
# #### Adding a column

# %%
df['Profit'] = df['total'] - df['fare'] - df['tip'] - df['tolls']

# %%
df['Profit']
# Out:
# 0       3.8
# 1       4.3
# 2       4.3
# 3       3.8
# 4       3.3
#        ...
# 6428    0.8
# 6429    0.8
# 6430    1.3
# 6431    0.8
# 6432    1.8
# Name: Profit, Length: 6433, dtype: float64

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df['Profit'] / 2
# Out:
# 0       1.90
# 1       2.15
# 2       2.15
# 3       1.90
# 4       1.65
#         ...
# 6428    0.40
# 6429    0.40
# 6430    0.65
# 6431    0.40
# 6432    0.90
# Name: Profit, Length: 6433, dtype: float64

# %%
df['Profit'] = df['Profit'] / 2

# %%
df['Profit']
# Out:
# 0       1.90
# 1       2.15
# 2       2.15
# 3       1.90
# 4       1.65
#         ...
# 6428    0.40
# 6429    0.40
# 6430    0.65
# 6431    0.40
# 6432    0.90
# Name: Profit, Length: 6433, dtype: float64

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df['payment'].fillna
# Out:
# <bound method NDFrame.fillna of 0       credit card
# 1              cash
# 2       credit card
# 3       credit card
# 4       credit card
#            ...
# 6428    credit card
# 6429    credit card
# 6430           cash
# 6431    credit card
# 6432    credit card
# Name: payment, Length: 6433, dtype: object>

# %%
df['payment'].fillna('other')
# Out:
# 0       credit card
# 1              cash
# 2       credit card
# 3       credit card
# 4       credit card
#            ...
# 6428    credit card
# 6429    credit card
# 6430           cash
# 6431    credit card
# 6432    credit card
# Name: payment, Length: 6433, dtype: object

# %%
df['payment'] = df['payment'].fillna('other')

# %%
df['payment'].isna
# Out:
# <bound method Series.isna of 0       credit card
# 1              cash
# 2       credit card
# 3       credit card
# 4       credit card
#            ...
# 6428    credit card
# 6429    credit card
# 6430           cash
# 6431    credit card
# 6432    credit card
# Name: payment, Length: 6433, dtype: object>

# %%
df.drop('Profit',axis=1,inplace=True)

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6433 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df['pickup_borough'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: pickup_borough, Length: 6433, dtype: bool

# %%
df.dropna(subset = 'pickup_borough')
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.dropna(subset = 'pickup_borough',inplace=True)

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df['pickup_borough']
# Out:
# 0       Manhattan
# 1       Manhattan
# 2       Manhattan
# 3       Manhattan
# 4       Manhattan
#           ...
# 6428    Manhattan
# 6429       Queens
# 6430     Brooklyn
# 6431     Brooklyn
# 6432     Brooklyn
# Name: pickup_borough, Length: 6407, dtype: object

# %%
df.iloc[4]
# Out:
# pickup             2019-03-30 13:27:42
# dropoff            2019-03-30 13:37:14
# passengers                           3
# distance                          2.16
# fare                               9.0
# tip                                1.1
# tolls                              0.0
# total                             13.4
# color                           yellow
# payment                    credit card
# pickup_zone               Midtown East
# dropoff_zone            Yorkville West
# pickup_borough               Manhattan
# dropoff_borough              Manhattan
# Name: 4, dtype: object

# %%
df.iloc[4, 7]
# Out:
# np.float64(13.4)

# %%
df.iloc[4, 7] = 15.0

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...
